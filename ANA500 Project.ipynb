# %% [markdown]
# ANA500 Project
#
# Dataset Source Link: https://www.openml.org/search?type=data&status=active&id=46255

# %%
import openml
import pandas as pd

# Get the dataset by ID
dataset = openml.datasets.get_dataset(46255)

# Get the data as a dataframe
X, y, categorical_indicator, attribute_names = dataset.get_data(
    dataset_format="dataframe", target=dataset.default_target_attribute
)

# Create a dataframe with features and target
df = pd.concat([X, y], axis=1)

print(df.head())
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196           2
# ...

# %%
print('Dataset Information:')
df.info()
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   uint8
#  2   Gender             2392 non-null   uint8
#  3   Ethnicity          2392 non-null   uint8
#  4   ParentalEducation  2392 non-null   uint8
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   uint8
#  7   Tutoring           2392 non-null   uint8
#  8   ParentalSupport    2392 non-null   uint8
#  9   Extracurricular    2392 non-null   uint8
#  10  Sports             2392 non-null   uint8
#  11  Music              2392 non-null   uint8
#  12  Volunteering       2392 non-null   uint8
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   uint8
# dtypes: float64(2), int64(1), uint8(12)
# ...

# %%
print('Descriptive Statistics:')
df.describe()
# Out:
# Descriptive Statistics:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# ...

# %%
#Explore Frequencies of Binary Categorical Variables
df.Gender.value_counts()
# Out:
# Gender
# 1    1222
# 0    1170
# Name: count, dtype: int64

# %%
df.Tutoring.value_counts()
# Out:
# Tutoring
# 0    1671
# 1     721
# Name: count, dtype: int64

# %%
df.Extracurricular.value_counts()
# Out:
# Extracurricular
# 0    1475
# 1     917
# Name: count, dtype: int64

# %%
df.Sports.value_counts()
# Out:
# Sports
# 0    1666
# 1     726
# Name: count, dtype: int64

# %%
df.Music.value_counts()
# Out:
# Music
# 0    1921
# 1     471
# Name: count, dtype: int64

# %%
df.Volunteering.value_counts()
# Out:
# Volunteering
# 0    2016
# 1     376
# Name: count, dtype: int64

# %% [markdown]
# Notes:
# - No missing values in any column
# - Per data dictionary:
#     - StudentID: Unique identifier for each student (e.g., 2737, 1403).
#     - Age: Age of the student (e.g., 16, 17, 18).
#     - Gender: Student's gender (0 for female, 1 for male).
#     - Ethnicity: Categorical representation of the student's ethnicity (e.g., 0, 1, 3; where each number represents a different group).
#     - ParentalEducation: Level of parental education (0 to 4 scale, from less to more educated).
#     - StudyTimeWeekly: Weekly study time in hours (e.g., 10.82, 11.51).
#     - Absences: Number of absences (e.g., 3, 18).
#     - Tutoring: Indicates if the student receives tutoring (0 for no, 1 for yes).
#     - ParentalSupport: Level of parental support (0 to 3 scale, from none to high).
#     - Extracurricular: Participation in extracurricular activities (0 for no, 1 for yes).
#     - Sports: Participation in sports (0 for no, 1 for yes).
#     - Music: Participation in music-related activities (0 for no, 1 for yes).
#     - Volunteering: Participation in volunteering activities (0 for no, 1 for yes).
#     - GPA: Grade Point Average of the student (e.g., 1.25, 2.85).
#     - GradeClass: Yearly grade classification (e.g., 2.0, 4.0; on a 0-4 scale).
# - 1222 males, 1170 females
# - Age ranges from 15 to 18; mean 16.5, median 16
# - StudyTimeWeekly ranges from 0.001 to 19.978; mean 9.77, median 9.71
# - Absences ranges from 0 to 29; mean 14.5, median 15
# - GPA mean 1.91, median 1.89
# - GradeClass mean 2.98, median 4.0
#
# Questions:
# - what are definitions of each value for Ethnicity?
#       - from researching commonly used dataset codings for ethnicity, 0 for not hispanic or latino, 1 for hispanic or latino, 2 for black or
#         african american, 3 for asian.
# - what are definitions of each value for ParentalEducation?
# - what are definitions of each value for ParentalSupport?
# - in what timespan is Absences measured (i.e. yearly? monthly? entirely of high school?)
#       - assuming yearly
# - Why are GradeClass scores so much higher than GPAs on average/according to the medians?

# %%
# Double Check for Missing Values
df.isnull().sum()
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
# Check for Duplicate Rows
df.duplicated().sum()
# Out:
# 0

# %%
# Examine Descriptive Statistics More Closely for Possible Outliers 
df.describe([x*0.1 for x in range(10)])
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 0%     1001.000000    15.000000     0.000000     0.000000           0.000000
# 10%    1240.100000    15.000000     0.000000     0.000000           0.000000
# 20%    1479.200000    15.000000     0.000000     0.000000           1.000000
# 30%    1718.300000    16.000000     0.000000     0.000000           1.000000
# 40%    1957.400000    16.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 60%    2435.600000    17.000000     1.000000     1.000000           2.000000
# ...

# %%
# Examine Distributions of Non-Binary Features Using Histograms: 
import seaborn as sns

#Age
fig = plt.figure(figsize=(4,3))
ax = fig.add_axes([0,0,1,1])
sns.countplot(data = df, x = 'Age')
ax.set_xlabel("Age", fontsize=15)
ax.set_ylabel("Count", fontsize=15);

# %%
# Ethnicity
print('Histogram of Ethnicity')
ethnicity = ['White', 'Latino', 'Black', 'Asian']
fig = plt.figure(figsize=(4,3))
ax = fig.add_axes([0,0,1,1])
sns.countplot(data = df, x = 'Ethnicity')
ax.set_xlabel("Ethnicity", fontsize=15)
ax.set_ylabel("Count", fontsize=15)
ax.set_xticklabels(ethnicity, rotation=45);
# Out:
# Histogram of Ethnicity
# /var/folders/rb/hbq90lbj0m705wt5bbtwzdl40000gn/T/ipykernel_26572/1365727727.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ethnicity, rotation=45);

# %%
#ParentalEducation
print('Histogram of ParentalEducation')
fig = plt.figure(figsize=(4,3))
ax = fig.add_axes([0,0,1,1])
sns.countplot(data = df, x = 'ParentalEducation')
ax.set_xlabel("ParentalEducation", fontsize=15)
ax.set_ylabel("Count", fontsize=15);
# Out:
# Histogram of ParentalEducation

# %%
#StudyTimeWeekly
print('Histogram of StudyTimeWeekly')
sns.displot(data=df['StudyTimeWeekly'])
# Out:
# Histogram of StudyTimeWeekly

# %%
# Create Categorical Variable from StudyTimeWeekly to look at Relationship with Target Variable

df.StudyTimeWeekly.describe()
# Out:
# count    2392.000000
# mean        9.771992
# std         5.652774
# min         0.001057
# 25%         5.043079
# 50%         9.705363
# 75%        14.408410
# max        19.978094
# Name: StudyTimeWeekly, dtype: float64

# %%
# Define Categories of StudyTimeWeekly

df['StudyTimeCat'] = np.where(df.StudyTimeWeekly < 5, 0, 
                              np.where(df.StudyTimeWeekly < 10, 1, 
                                       np.where(df.StudyTimeWeekly < 15, 2, 3)))
#Check New Variable
df.head(25)
# Out:
#     StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0        1001   17       1          0                  2        19.833723
# 1        1002   18       0          0                  1        15.408756
# 2        1003   15       0          2                  3         4.210570
# 3        1004   17       1          0                  3        10.028829
# 4        1005   17       1          0                  2         4.672495
# 5        1006   18       0          0                  1         8.191219
# 6        1007   15       0          1                  1        15.601680
# 7        1008   15       1          1                  4        15.424496
# 8        1009   17       0          0                  0         4.562008
# 9        1010   16       1          0                  1        18.444466
# 10       1011   17       0          0                  1        11.851364
# 11       1012   17       0          0                  1         7.598486
# ...

# %%
# StudyTimeCat Disbtribution
level = ['< 5','< 10','< 15','< 20']
fig = plt.figure(figsize=(4,3))
ax = fig.add_axes([0,0,1,1])
sns.countplot(data = df, x = 'StudyTimeCat')
ax.set_xlabel("StudyTimeWeekly (in hours)", fontsize=15)
ax.set_ylabel("Count", fontsize=15)
ax.set_xticklabels(level, rotation=0);
# Out:
# /var/folders/rb/hbq90lbj0m705wt5bbtwzdl40000gn/T/ipykernel_26572/2625882445.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(level, rotation=0);

# %%
#Absences
print('Histogram of Absences')
sns.displot(data=df['Absences'])
# Out:
# Histogram of Absences

# %%
# Create Categorical Variable from Absences to look at Relationship with Target Variable

df.Absences.describe()
# Out:
# count    2392.000000
# mean       14.541388
# std         8.467417
# min         0.000000
# 25%         7.000000
# 50%        15.000000
# 75%        22.000000
# max        29.000000
# Name: Absences, dtype: float64

# %%
# Define Categories of Absences

df['AbsenceCat'] = np.where(df.Absences < 6, 0, 
                              np.where(df.Absences < 12, 1, 
                                       np.where(df.Absences < 18, 2, 
                                                np.where(df.Absences <24, 3, 4))))
#Check New Variable
df.head(25)
# Out:
#     StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0        1001   17       1          0                  2        19.833723
# 1        1002   18       0          0                  1        15.408756
# 2        1003   15       0          2                  3         4.210570
# 3        1004   17       1          0                  3        10.028829
# 4        1005   17       1          0                  2         4.672495
# 5        1006   18       0          0                  1         8.191219
# 6        1007   15       0          1                  1        15.601680
# 7        1008   15       1          1                  4        15.424496
# 8        1009   17       0          0                  0         4.562008
# 9        1010   16       1          0                  1        18.444466
# 10       1011   17       0          0                  1        11.851364
# 11       1012   17       0          0                  1         7.598486
# ...

# %%
# AbsenceCat
level = ['0-5','6-11','12-17','18-23','24-29']
fig = plt.figure(figsize=(4,3))
ax = fig.add_axes([0,0,1,1])
sns.countplot(data = df, x = 'AbsenceCat')
ax.set_xlabel("Absences (yearly)", fontsize=15)
ax.set_ylabel("Count", fontsize=15)
ax.set_xticklabels(level, rotation=0);
# Out:
# /var/folders/rb/hbq90lbj0m705wt5bbtwzdl40000gn/T/ipykernel_26572/682641568.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(level, rotation=0);

# %%
#ParentalSupport
print('Histogram of ParentalSupport')
fig = plt.figure(figsize=(4,3))
ax = fig.add_axes([0,0,1,1])
sns.countplot(data = df, x = 'ParentalSupport')
ax.set_xlabel("ParentalSupport", fontsize=15)
ax.set_ylabel("Count", fontsize=15);
# Out:
# Histogram of ParentalSupport

# %%
#GPA
print('Histogram of GPA')
sns.displot(data=df['GPA'])
# Out:
# Histogram of GPA

# %%
# Create Categorical Variable from GPA

df.GPA.describe()
# Out:
# count    2392.000000
# mean        1.906186
# std         0.915156
# min         0.000000
# 25%         1.174803
# 50%         1.893393
# 75%         2.622216
# max         4.000000
# Name: GPA, dtype: float64

# %%
# Define Categories of GPA

df['GPACat'] = np.where(df.GPA < 0.5, 0, 
                              np.where(df.GPA < 1, 1, 
                                       np.where(df.GPA < 1.5, 2, 
                                                np.where(df.GPA <2, 3,
                                                         np.where(df.GPA < 2.5, 4, 
                                                                   np.where(df.GPA < 3, 5, 
                                                                            np.where(df.GPA < 3.5, 6, 7)))))))
#Check New Variable
df.head(25)
# Out:
#     StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0        1001   17       1          0                  2        19.833723
# 1        1002   18       0          0                  1        15.408756
# 2        1003   15       0          2                  3         4.210570
# 3        1004   17       1          0                  3        10.028829
# 4        1005   17       1          0                  2         4.672495
# 5        1006   18       0          0                  1         8.191219
# 6        1007   15       0          1                  1        15.601680
# 7        1008   15       1          1                  4        15.424496
# 8        1009   17       0          0                  0         4.562008
# 9        1010   16       1          0                  1        18.444466
# 10       1011   17       0          0                  1        11.851364
# 11       1012   17       0          0                  1         7.598486
# ...

# %%
# GPACat
level = ['<0.5','<1.0','<1.5','<2.0','<2.5','<3.0','<3.5','<=4.0']
fig = plt.figure(figsize=(4,3))
ax = fig.add_axes([0,0,1,1])
sns.countplot(data = df, x = 'GPACat')
ax.set_xlabel("GPA", fontsize=15)
ax.set_ylabel("Count", fontsize=15)
ax.set_xticklabels(level, rotation=0);
# Out:
# /var/folders/rb/hbq90lbj0m705wt5bbtwzdl40000gn/T/ipykernel_26572/1752210209.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(level, rotation=0);

# %%
#GradeClass
print('Histogram of GradeClass')
fig = plt.figure(figsize=(4,3))
ax = fig.add_axes([0,0,1,1])
sns.countplot(data = df, x = 'GradeClass')
ax.set_xlabel("GradeClass", fontsize=15)
ax.set_ylabel("Count", fontsize=15);
# Out:
# Histogram of GradeClass

# %%
# Verify that StudentID column has all unique values (i.e. no students repeated)
import numpy as np
print('True or False? \n Every value of StudentID is unique:', df['StudentID'].is_unique)
# Out:
# True or False?
#  Every value of StudentID is unique: True

# %%
# Change Data Index to StudentID

df = df.set_index('StudentID')
df.head()
# Out:
#            Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# StudentID
# 1001        17       1          0                  2        19.833723
# 1002        18       0          0                  1        15.408756
# 1003        15       0          2                  3         4.210570
# 1004        17       1          0                  3        10.028829
# 1005        17       1          0                  2         4.672495
#
#            Absences  Tutoring  ParentalSupport  Extracurricular  Sports  \
# StudentID
# 1001              7         1                2                0       0
# 1002              0         0                1                0       0
# 1003             26         0                2                0       0
# 1004             14         0                3                1       0
# 1005             17         1                3                0       0
#
#            Music  Volunteering       GPA  GradeClass  StudyTimeCat  \
# StudentID
# ...

# %%
# Create Target Variable

df['AtRisk'] = np.where((df.GPA >= 0) & (df.GPA <=1.67), 1, 0)
df[['GPA', 'AtRisk']].head(25)
# Out:
#                 GPA  AtRisk
# StudentID
# 1001       2.929196       0
# 1002       3.042915       0
# 1003       0.112602       1
# 1004       2.054218       0
# 1005       1.288061       1
# 1006       3.084184       0
# 1007       2.748237       0
# 1008       1.360143       1
# 1009       2.896819       0
# 1010       3.573474       0
# 1011       2.147172       0
# 1012       1.559595       1
# 1013       1.520078       1
# 1014       1.751581       0
# 1015       2.396788       0
# 1016       1.341521       1
# 1017       2.232175       0
# 1018       1.384404       1
# 1019       0.469553       1
# 1020       2.395784       0
# 1021       2.778411       0
# 1022       0.346894       1
# 1023       0.312546       1
# 1024       1.770132       0
# 1025       1.505156       1

# %%
# Count Frequency of Target Variable
df['AtRisk'].value_counts()
# Out:
# AtRisk
# 0    1388
# 1    1004
# Name: count, dtype: int64

# %%
#Drop StudyTimeCat, AbsenceCat, and GPACat to restore dataset to original variables

df.drop(['StudyTimeCat', 'AbsenceCat', "GPACat"], axis=1, inplace=True)

# %%
df.head()
# Out:
#            Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# StudentID
# 1001        17       1          0                  2        19.833723
# 1002        18       0          0                  1        15.408756
# 1003        15       0          2                  3         4.210570
# 1004        17       1          0                  3        10.028829
# 1005        17       1          0                  2         4.672495
#
#            Absences  Tutoring  ParentalSupport  Extracurricular  Sports  \
# StudentID
# 1001              7         1                2                0       0
# 1002              0         0                1                0       0
# 1003             26         0                2                0       0
# 1004             14         0                3                1       0
# 1005             17         1                3                0       0
#
#            Music  Volunteering       GPA  GradeClass  AtRisk
# StudentID
# ...

# %%
# Correlation Heat Map of Variables

sns.heatmap(df.corr());

# %%
# GPA is used to define AtRisk (target variable), and GradeClass is strongly correlated to GPA, so drop these two variables

df.drop(['GPA', 'GradeClass'], axis=1, inplace=True)

# %%
df.head()
# Out:
#            Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# StudentID
# 1001        17       1          0                  2        19.833723
# 1002        18       0          0                  1        15.408756
# 1003        15       0          2                  3         4.210570
# 1004        17       1          0                  3        10.028829
# 1005        17       1          0                  2         4.672495
#
#            Absences  Tutoring  ParentalSupport  Extracurricular  Sports  \
# StudentID
# 1001              7         1                2                0       0
# 1002              0         0                1                0       0
# 1003             26         0                2                0       0
# 1004             14         0                3                1       0
# 1005             17         1                3                0       0
#
#            Music  Volunteering  AtRisk
# StudentID
# ...

# %%
# Investigate Variable Inflation Factor (VIF) scores among remaining predictor variables

import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

X = add_constant(df)

#Drop Target Variable when Investigating VIF
X.drop(['AtRisk'], axis=1, inplace=True)

pd.Series([variance_inflation_factor(X.values, i) 
               for i in range(X.shape[1])], 
              index=X.columns)
# Out:
# const                232.096195
# Age                    1.008050
# Gender                 1.004085
# Ethnicity              1.004501
# ParentalEducation      1.005870
# StudyTimeWeekly        1.003410
# Absences               1.005220
# Tutoring               1.005462
# ParentalSupport        1.004679
# Extracurricular        1.001835
# Sports                 1.004609
# Music                  1.004414
# Volunteering           1.003994
# dtype: float64

# %%
# Start Exploring Independent Variable Relationships with Target Variable

import matplotlib as mpl
import matplotlib.pyplot as plt

# Target Variable Breakdown
fig = plt.figure(figsize=(4,3))
ax = fig.add_axes([0,0,1,1])
sns.countplot(data = df, x = 'AtRisk')
# Out:
# <Axes: xlabel='AtRisk', ylabel='count'>

# %%
# Age vs. AtRisk

fig = plt.figure(figsize=(4,3))
ax = fig.add_axes([0,0,1,1])
sns.countplot(data = df, x = 'Age', hue = 'AtRisk')
plt.legend(['Not At Risk', 'At Risk'], bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.title('At Risk Students By Age', fontsize=22)
ax.set_xlabel("Age", fontsize=15)
ax.set_ylabel("Count", fontsize=15);

# %%
# Gender vs. AtRisk
gender = ['Female', 'Male']
fig = plt.figure(figsize=(4,3))
ax = fig.add_axes([0,0,1,1])
sns.countplot(data = df, x = 'Gender', hue = 'AtRisk')
plt.legend(['Not At Risk', 'At Risk'], bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.title('At Risk Students By Gender', fontsize=22)
ax.set_xlabel("Gender", fontsize=15)
ax.set_ylabel("Count", fontsize=15)
ax.set_xticklabels(gender);
# Out:
# /var/folders/rb/hbq90lbj0m705wt5bbtwzdl40000gn/T/ipykernel_26572/1182350224.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(gender);

# %%
# Ethnicity vs. AtRisk
ethnicity = ['White', 'Latino', 'Black', 'Asian']
fig = plt.figure(figsize=(4,3))
ax = fig.add_axes([0,0,1,1])
sns.countplot(data = df, x = 'Ethnicity', hue = 'AtRisk')
plt.legend(['Not At Risk', 'At Risk'], bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.title('At Risk Students By Ethnicity', fontsize=22)
ax.set_xlabel("Ethnicity", fontsize=15)
ax.set_ylabel("Count", fontsize=15)
ax.set_xticklabels(ethnicity, rotation=45);
# Out:
# /var/folders/rb/hbq90lbj0m705wt5bbtwzdl40000gn/T/ipykernel_26572/1123944340.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ethnicity, rotation=45);

# %%
# ParentalEducation vs. AtRisk
fig = plt.figure(figsize=(4,3))
ax = fig.add_axes([0,0,1,1])
sns.countplot(data = df, x = 'ParentalEducation', hue = 'AtRisk')
plt.legend(['Not At Risk', 'At Risk'], bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.title('At Risk Students By Parental Education', fontsize=19)
ax.set_xlabel("ParentalEducation", fontsize=15)
ax.set_ylabel("Count", fontsize=15);

# %%
# Tutoring vs. AtRisk
binary=['no', 'yes']
fig = plt.figure(figsize=(4,3))
ax = fig.add_axes([0,0,1,1])
sns.countplot(data = df, x = 'Tutoring', hue = 'AtRisk')
plt.legend(['Not At Risk', 'At Risk'], bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.title('At Risk Students By Tutoring', fontsize=22)
ax.set_xlabel("Tutoring", fontsize=15)
ax.set_ylabel("Count", fontsize=15)
ax.set_xticklabels(binary);
# Out:
# /var/folders/rb/hbq90lbj0m705wt5bbtwzdl40000gn/T/ipykernel_26572/2710925022.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(binary);

# %%
# ParentalSupport vs. AtRisk

fig = plt.figure(figsize=(4,3))
ax = fig.add_axes([0,0,1,1])
sns.countplot(data = df, x = 'ParentalSupport', hue = 'AtRisk')
plt.legend(['Not At Risk', 'At Risk'], bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.title('At Risk Students By ParentalSupport', fontsize=20)
ax.set_xlabel("ParentalSupport", fontsize=15)
ax.set_ylabel("Count", fontsize=15);

# %%
# Extracurricular vs. AtRisk
binary=['no', 'yes']
fig = plt.figure(figsize=(4,3))
ax = fig.add_axes([0,0,1,1])
sns.countplot(data = df, x = 'Extracurricular', hue = 'AtRisk')
plt.legend(['Not At Risk', 'At Risk'], bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.title('At Risk Students By Extracurricular', fontsize=21)
ax.set_xlabel("Extracurricular", fontsize=15)
ax.set_ylabel("Count", fontsize=15)
ax.set_xticklabels(binary);
# Out:
# /var/folders/rb/hbq90lbj0m705wt5bbtwzdl40000gn/T/ipykernel_26572/1663852736.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(binary);

# %%
# Sports vs. AtRisk
binary=['no', 'yes']
fig = plt.figure(figsize=(4,3))
ax = fig.add_axes([0,0,1,1])
sns.countplot(data = df, x = 'Sports', hue = 'AtRisk')
plt.legend(['Not At Risk', 'At Risk'], bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.title('At Risk Students By Sports', fontsize=22)
ax.set_xlabel("Sports", fontsize=15)
ax.set_ylabel("Count", fontsize=15)
ax.set_xticklabels(binary);
# Out:
# /var/folders/rb/hbq90lbj0m705wt5bbtwzdl40000gn/T/ipykernel_26572/2263047819.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(binary);

# %%
# Music vs. AtRisk
binary=['no', 'yes']
fig = plt.figure(figsize=(4,3))
ax = fig.add_axes([0,0,1,1])
sns.countplot(data = df, x = 'Music', hue = 'AtRisk')
plt.legend(['Not At Risk', 'At Risk'], bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.title('At Risk Students By Music', fontsize=22)
ax.set_xlabel("Music", fontsize=15)
ax.set_ylabel("Count", fontsize=15)
ax.set_xticklabels(binary);
# Out:
# /var/folders/rb/hbq90lbj0m705wt5bbtwzdl40000gn/T/ipykernel_26572/2445285628.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(binary);

# %%
# Volunteering vs. AtRisk
binary=['no', 'yes']
fig = plt.figure(figsize=(4,3))
ax = fig.add_axes([0,0,1,1])
sns.countplot(data = df, x = 'Volunteering', hue = 'AtRisk')
plt.legend(['Not At Risk', 'At Risk'], bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.title('At Risk Students By Volunteering', fontsize=22)
ax.set_xlabel("Volunteering", fontsize=15)
ax.set_ylabel("Count", fontsize=15)
ax.set_xticklabels(binary);
# Out:
# /var/folders/rb/hbq90lbj0m705wt5bbtwzdl40000gn/T/ipykernel_26572/2203467170.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(binary);

# %%
# Recreate Categories of StudyTimeWeekly

df['StudyTimeCat'] = np.where(df.StudyTimeWeekly < 5, 0, 
                              np.where(df.StudyTimeWeekly < 10, 1, 
                                       np.where(df.StudyTimeWeekly < 15, 2, 3)))

# %%
# StudyTimeCat vs. AtRisk
level = ['< 5','< 10','< 15','< 20']
fig = plt.figure(figsize=(4,3))
ax = fig.add_axes([0,0,1,1])
sns.countplot(data = df, x = 'StudyTimeCat', hue = 'AtRisk')
plt.legend(['Not At Risk', 'At Risk'], bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.title('At Risk Students By Weekly Study Time Level', fontsize=16)
ax.set_xlabel("Weekly Study Time (in hours)", fontsize=15)
ax.set_ylabel("Count", fontsize=15)
ax.set_xticklabels(level, rotation=0);
# Out:
# /var/folders/rb/hbq90lbj0m705wt5bbtwzdl40000gn/T/ipykernel_26572/3637051206.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(level, rotation=0);

# %%
# Recreate Categories of Absences

df['AbsenceCat'] = np.where(df.Absences < 6, 0, 
                              np.where(df.Absences < 12, 1, 
                                       np.where(df.Absences < 18, 2, 
                                                np.where(df.Absences <24, 3, 4))))

# %%
# AbsenceCat vs. AtRisk
level = ['0-5','6-11','12-17','18-23','24-29']
fig = plt.figure(figsize=(4,3))
ax = fig.add_axes([0,0,1,1])
sns.countplot(data = df, x = 'AbsenceCat', hue = 'AtRisk')
plt.legend(['Not At Risk', 'At Risk'], bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.title('At Risk Students By Absence Level', fontsize=22)
ax.set_xlabel("Absences (yearly)", fontsize=15)
ax.set_ylabel("Count", fontsize=15)
ax.set_xticklabels(level, rotation=0);
# Out:
# /var/folders/rb/hbq90lbj0m705wt5bbtwzdl40000gn/T/ipykernel_26572/29377835.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(level, rotation=0);

# %%
#Dummy Encode Ethnicity (because numbered categories are nominal, not ordinal, so do not want model to make meaning of numbers)

df["Ethnicity"] = df["Ethnicity"].astype("category")
dummy_pred = pd.get_dummies(df, prefix_sep='_', dtype='int', drop_first=True)

# Re-add original Ethnicity variable to check dummy encoding
df2 = pd.concat([dummy_pred, df["Ethnicity"]], axis = 1)
df2.head(20)
# Out:
#            Age  Gender  ParentalEducation  StudyTimeWeekly  Absences  \
# StudentID
# 1001        17       1                  2        19.833723         7
# 1002        18       0                  1        15.408756         0
# 1003        15       0                  3         4.210570        26
# 1004        17       1                  3        10.028829        14
# 1005        17       1                  2         4.672495        17
# 1006        18       0                  1         8.191219         0
# 1007        15       0                  1        15.601680        10
# 1008        15       1                  4        15.424496        22
# 1009        17       0                  0         4.562008         1
# 1010        16       1                  1        18.444466         0
# 1011        17       0                  1        11.851364        11
# 1012        17       0                  1         7.598486        15
# ...

# %%
#Rename Ethnicity dummy variables so more clear

df2 = df2.rename(columns = {"Ethnicity_1": "Eth_Latino", 
                                  "Ethnicity_2":"Eth_Black", 
                                  "Ethnicity_3": "Eth_Asian"})
df2.head(20)
# Out:
#            Age  Gender  ParentalEducation  StudyTimeWeekly  Absences  \
# StudentID
# 1001        17       1                  2        19.833723         7
# 1002        18       0                  1        15.408756         0
# 1003        15       0                  3         4.210570        26
# 1004        17       1                  3        10.028829        14
# 1005        17       1                  2         4.672495        17
# 1006        18       0                  1         8.191219         0
# 1007        15       0                  1        15.601680        10
# 1008        15       1                  4        15.424496        22
# 1009        17       0                  0         4.562008         1
# 1010        16       1                  1        18.444466         0
# 1011        17       0                  1        11.851364        11
# 1012        17       0                  1         7.598486        15
# ...

# %%
#Re-drop original categorical Ethnicity variable

df2 = df2.drop(["Ethnicity"], axis = 1)
df2.head()
# Out:
#            Age  Gender  ParentalEducation  StudyTimeWeekly  Absences  \
# StudentID
# 1001        17       1                  2        19.833723         7
# 1002        18       0                  1        15.408756         0
# 1003        15       0                  3         4.210570        26
# 1004        17       1                  3        10.028829        14
# 1005        17       1                  2         4.672495        17
#
#            Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# StudentID
# 1001              1                2                0       0      1
# 1002              0                1                0       0      0
# 1003              0                2                0       0      0
# 1004              0                3                1       0      0
# 1005              1                3                0       0      0
#
#            Volunteering  AtRisk  StudyTimeCat  AbsenceCat  Eth_Latino  \
# StudentID
# ...

# %%
# Re-examine correlations before splitting dataset into train/test sets
corr_matrix = df2.corr()
corr_matrix["AtRisk"].sort_values(ascending=False)
# Out:
# AtRisk               1.000000
# Absences             0.798356
# AbsenceCat           0.790335
# ParentalEducation    0.035383
# Gender               0.023872
# Age                  0.013933
# Volunteering         0.012057
# Eth_Black           -0.004849
# Eth_Asian           -0.009285
# Sports              -0.028974
# Eth_Latino          -0.031262
# Extracurricular     -0.046858
# Music               -0.054734
# Tutoring            -0.093460
# StudyTimeCat        -0.107949
# StudyTimeWeekly     -0.110316
# ParentalSupport     -0.124180
# Name: AtRisk, dtype: float64

# %% [markdown]
# It is clear from the sorted correlation list above that Absences is highly correlated with AtRisk. Therefore, we will want to ensure that our training and testing datasets are equally representative of the various levels of Absences. We can use are already generated AbsenceCat variable for this.

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
# Use Stratified Shuffle Split to create 80/20 train/test sets

from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(df2, test_size=0.2, random_state=88, stratify=df2["AbsenceCat"])

# %%
# Let’s see if this worked as expected:

print("train_set ratios of", train_set["AbsenceCat"].value_counts() / len(train_set))
print("\ntest_set ratios of", test_set["AbsenceCat"].value_counts() / len(test_set))
# Out:
# train_set ratios of AbsenceCat
# 2    0.215891
# 3    0.208573
# 1    0.193936
# 4    0.192891
# 0    0.188709
# Name: count, dtype: float64
#
# test_set ratios of AbsenceCat
# 2    0.215031
# 3    0.208768
# 1    0.194154
# 4    0.192067
# 0    0.189979
# Name: count, dtype: float64

# %%
# Remove the AbsenceCat and StudyTimeCat variables from both train and test sets so the data is back to its original state

for set_ in (train_set, test_set):
    set_.drop(["AbsenceCat", "StudyTimeCat"], axis=1, inplace=True)

train_set.head()
# Out:
#            Age  Gender  ParentalEducation  StudyTimeWeekly  Absences  \
# StudentID
# 3313        17       0                  3         1.994524        28
# 1671        15       1                  2        16.643249        16
# 2427        17       0                  2        17.224645        13
# 3334        15       0                  0         3.206181        10
# 3029        16       1                  0        18.656924         0
#
#            Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# StudentID
# 3313              0                4                1       0      0
# 1671              0                2                1       0      0
# 2427              0                2                1       1      0
# 3334              0                1                1       1      0
# 3029              1                4                1       0      0
#
#            Volunteering  AtRisk  Eth_Latino  Eth_Black  Eth_Asian
# StudentID
# ...

# %%
# Divide train and test sets into predictor vs target variable sets for modeling purposes

x_train = train_set.drop(["AtRisk"], axis = 1)
y_train = train_set["AtRisk"]

x_test = test_set.drop(["AtRisk"], axis = 1)
y_test = test_set["AtRisk"]

print("x_train.shape: ", x_train.shape)
print("y_train.shape: ", y_train.shape)
print("x_test.shape: ", x_test.shape)
print("y_test.shape: ", y_test.shape)
# Out:
# x_train.shape:  (1913, 14)
# y_train.shape:  (1913,)
# x_test.shape:  (479, 14)
# y_test.shape:  (479,)

# %%
# Scale Datasets

from sklearn.preprocessing import MinMaxScaler
from sklearn import svm

from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.model_selection import cross_val_score, GridSearchCV

#MinMaxScaler to preserve original distributions (good because no outliers in dataset)
minmax_scale = MinMaxScaler()
x_train_scaled = minmax_scale.fit_transform(x_train)
x_test_scaled = minmax_scale.fit_transform(x_test)

# %%
# Logistic Regression Modeling
from sklearn.linear_model import LogisticRegression

logit_reg = LogisticRegression(penalty = "l2", C = 1e42, solver = "liblinear")
logit_reg.fit(x_train_scaled, y_train)
# Out:
# LogisticRegression(C=1e+42, solver='liblinear')

# %%
# Find Logistic Regression Parameters:
from dmba import AIC_score, classificationSummary, gainsChart, liftChart

coefficients = logit_reg.coef_[0]

print("Intercept: ", logit_reg.intercept_[0])
print("\nCoefficients: ", sorted(zip(coefficients, x_train.columns), reverse=True))
print("\nLogistic Regression AIC: ", AIC_score(y_test, logit_reg.predict(x_test_scaled), df = len(x_train.columns)+1))
# Out:
# Intercept:  -7.911234133100414
#
# Coefficients:  [(26.076062311965842, 'Absences'), (0.31029170129059347, 'Eth_Asian'), (0.2854266150499625, 'Age'), (0.2633750188105499, 'Volunteering'), (0.16688667644937552, 'ParentalEducation'), (0.14908417583683864, 'Gender'), (-0.1433466200166256, 'Eth_Black'), (-0.27879736428136986, 'Eth_Latino'), (-1.4478176459892074, 'Sports'), (-1.4765769733696898, 'Music'), (-1.5558633035041665, 'Extracurricular'), (-2.2462828897868627, 'Tutoring'), (-5.164039710528826, 'ParentalSupport'), (-5.783174929131145, 'StudyTimeWeekly')]
#
# Logistic Regression AIC:  151.60410017072445

# %%
#Training confusion matrix

print ("Training")
classificationSummary(y_train, logit_reg.predict(x_train_scaled))

#Testing confusion matrix

print ("\n\nTesting")
classificationSummary(y_test, logit_reg.predict(x_test_scaled))
# Out:
# Training
# Confusion Matrix (Accuracy 0.9451)
#
#        Prediction
# Actual    0    1
#      0 1063   52
#      1   53  745
#
#
# Testing
# Confusion Matrix (Accuracy 0.9248)
#
#        Prediction
# Actual   0   1
#      0 254  19
#      1  17 189

# %%
#Evaluate Confusion Matrices of Logistic Regression Model

from sklearn.metrics import classification_report

target_names = ['Not At Risk', 'At Risk']

print("Training Set Metrics")
print(classification_report(y_train, logit_reg.predict(x_train_scaled), target_names=target_names))

print("Testing Set Metrics")
print(classification_report(y_test, logit_reg.predict(x_test_scaled), target_names=target_names))
# Out:
# Training Set Metrics
#               precision    recall  f1-score   support
#
#  Not At Risk       0.95      0.95      0.95      1115
#      At Risk       0.93      0.93      0.93       798
#
#     accuracy                           0.95      1913
#    macro avg       0.94      0.94      0.94      1913
# weighted avg       0.95      0.95      0.95      1913
#
# Testing Set Metrics
#               precision    recall  f1-score   support
#
#  Not At Risk       0.94      0.93      0.93       273
#      At Risk       0.91      0.92      0.91       206
#
#     accuracy                           0.92       479
#    macro avg       0.92      0.92      0.92       479
# weighted avg       0.92      0.92      0.92       479

# %%
# Gains & Lift Charts
logit_reg_preda = logit_reg.predict_proba(x_test_scaled)
logit_result = pd.DataFrame({
    "Actual": y_test,
    "p(0)": [i[0] for i in logit_reg_preda],
    "p(1)": [i[1] for i in logit_reg_preda],
    "Predicted": logit_reg.predict(x_test_scaled),
})

# Sort by predicted probabilities of class 1
logit_result = logit_result.sort_values(by=["p(1)"], ascending=False)

# Plot Gains and Lift charts
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

# Plot Gains Chart
gainsChart(logit_result["Actual"], ax=axes[0])

# Plot Lift Chart
liftChart(logit_result["p(1)"], title="Logisitic Regression Lift Chart", ax=axes[1])
# Out:
# <Axes: title={'center': 'Logisitic Regression Lift Chart'}, xlabel='Percentile', ylabel='Lift'>

# %%
#Area Under the ROC Curve
from sklearn import metrics
import matplotlib.pyplot as plt

y_pred_proba = logit_reg.predict_proba(x_test_scaled)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="logit_reg, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %% [markdown]
# Coefficients from logit_reg:
#
#    Absences: 26.08
#    Eth_Asian: 0.31
#    Age: 0.29
#    Volunteering: 0.26
#    ParentalEducation: 0.17
#    Gender: 0.15
#    Eth_Black: -0.14
#    Eth_Latino: -0.28
#    Sports: -1.45
#    Music: -1.48
#    Extracurricular: -1.56
#    Tutoring: -2.25
#    ParentalSupport: -5.16
#    StudyTimeWeekly: -5.78

# %%
#Drop variables that had parameters closest to zero (i.e. between 0.4 to -0.4) in previous Logistic Regression model

x_train_scaled2 = pd.DataFrame(x_train_scaled, columns = x_train.columns)
x_test_scaled2 = pd.DataFrame(x_test_scaled, columns = x_test.columns)

for set_ in (x_train_scaled2, x_test_scaled2):
    set_.drop(["Eth_Asian", "Age", "Volunteering", "ParentalEducation", "Gender", "Eth_Black", "Eth_Latino"], axis=1, inplace=True)

print("x_train_scaled2.shape: ", x_train_scaled2.shape)
print("x_test_scaled2.shape: ", x_test_scaled2.shape)
# Out:
# x_train_scaled2.shape:  (1913, 7)
# x_test_scaled2.shape:  (479, 7)

# %%
# Train Logistic Regression Model to Reduced Dataset

logit_reg2 = LogisticRegression(penalty = "l2", C = 1e42, solver = "liblinear")
logit_reg2.fit(x_train_scaled2, y_train)
# Out:
# LogisticRegression(C=1e+42, solver='liblinear')

# %%
# Find Logistic Regression Parameters for New Model:

coefficients = logit_reg2.coef_[0]

print("Intercept: ", logit_reg2.intercept_[0])
print("\nCoefficients: ", sorted(zip(coefficients, x_train_scaled2.columns), reverse=True))
print("\nLogistic Regression 2 AIC: ", AIC_score(y_test, logit_reg2.predict(x_test_scaled2), df = len(x_train_scaled2.columns)+1))
# Out:
# Intercept:  -7.62633149061021
#
# Coefficients:  [(25.962582346799692, 'Absences'), (-1.4383619646282684, 'Music'), (-1.4815010258934895, 'Sports'), (-1.5445163682138296, 'Extracurricular'), (-2.232289224733519, 'Tutoring'), (-5.132023974831828, 'ParentalSupport'), (-5.715610612643455, 'StudyTimeWeekly')]
#
# Logistic Regression 2 AIC:  124.11025010367712

# %%
#Training confusion matrix for 2nd model

print ("2nd Training")
classificationSummary(y_train, logit_reg2.predict(x_train_scaled2))

#Testing confusion matrix for 2nd model

print ("\n\n2nd Testing")
classificationSummary(y_test, logit_reg2.predict(x_test_scaled2))
# Out:
# 2nd Training
# Confusion Matrix (Accuracy 0.9430)
#
#        Prediction
# Actual    0    1
#      0 1064   51
#      1   58  740
#
#
# 2nd Testing
# Confusion Matrix (Accuracy 0.9269)
#
#        Prediction
# Actual   0   1
#      0 254  19
#      1  16 190

# %%
#Evaluate Confusion Matrices of 2nd Model

target_names = ['Not At Risk', 'At Risk']

print("2nd Training Set Metrics")
print(classification_report(y_train, logit_reg2.predict(x_train_scaled2), target_names=target_names))

print("2nd Testing Set Metrics")
print(classification_report(y_test, logit_reg2.predict(x_test_scaled2), target_names=target_names))
# Out:
# 2nd Training Set Metrics
#               precision    recall  f1-score   support
#
#  Not At Risk       0.95      0.95      0.95      1115
#      At Risk       0.94      0.93      0.93       798
#
#     accuracy                           0.94      1913
#    macro avg       0.94      0.94      0.94      1913
# weighted avg       0.94      0.94      0.94      1913
#
# 2nd Testing Set Metrics
#               precision    recall  f1-score   support
#
#  Not At Risk       0.94      0.93      0.94       273
#      At Risk       0.91      0.92      0.92       206
#
#     accuracy                           0.93       479
#    macro avg       0.92      0.93      0.93       479
# weighted avg       0.93      0.93      0.93       479

# %%
# Gains & Lift Charts
logit_reg2_preda = logit_reg2.predict_proba(x_test_scaled2)
logit_result2 = pd.DataFrame({
    "Actual": y_test,
    "p(0)": [i[0] for i in logit_reg2_preda],
    "p(1)": [i[1] for i in logit_reg2_preda],
    "Predicted": logit_reg2.predict(x_test_scaled2),
})

# Sort by predicted probabilities of class 1
logit_result2 = logit_result2.sort_values(by=["p(1)"], ascending=False)

# Plot Gains Chart for Both Logit Reg Models
fig, ax = plt.subplots(figsize = (8,6))
gainsChart(logit_result["Actual"], label = "logit_reg", color = "r", ax = ax)
gainsChart(logit_result2["Actual"], label = "logit_reg2", color = "b", ax = ax)                         
plt.legend()
plt.title("Gains Chart for Both Logit Reg Models")
# Out:
# Text(0.5, 1.0, 'Gains Chart for Both Logit Reg Models')

# %%
# Lift Charts
fig, axes = plt.subplots(
nrows = 1,
ncols = 2,
figsize = (15,6))
liftChart(logit_result["Actual"], title = "Logistic Regression 1 Lift Chart", ax = axes[0])
liftChart(logit_result2["Actual"], title = "Logistic Regression 2 Lift Chart", ax = axes[1])
fig.suptitle("Lift Charts by Logistic Regression Model")
# Out:
# Text(0.5, 0.98, 'Lift Charts by Logistic Regression Model')

# %%
#Area Under the 2nd ROC Curve

y_pred_proba2 = logit_reg2.predict_proba(x_test_scaled2)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba2)
auc = metrics.roc_auc_score(y_test, y_pred_proba2)
plt.plot(fpr,tpr,label="logit_reg2, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %%
#Support Vector Machine Model

#SVM - Default Kernal; Radial Basis Function (RBF)

svm_model = svm.SVC(random_state = 88, probability = True)
svm_model.fit(x_train_scaled, y_train)

print("RBF SVM Training Set")
classificationSummary(y_train, svm_model.predict(x_train_scaled))
print("\nRBF SVM Testing Set")
classificationSummary(y_test, svm_model.predict(x_test_scaled))
# Out:
# RBF SVM Training Set
# Confusion Matrix (Accuracy 0.9592)
#
#        Prediction
# Actual    0    1
#      0 1084   31
#      1   47  751
#
# RBF SVM Testing Set
# Confusion Matrix (Accuracy 0.9290)
#
#        Prediction
# Actual   0   1
#      0 256  17
#      1  17 189

# %%
#Evaluate Confusion Matrices of SVM - Linear Model

target_names = ['Not At Risk', 'At Risk']

print("SVM-RBF Training Set Metrics")
print(classification_report(y_train, svm_model.predict(x_train_scaled), target_names=target_names))

print("SVM-RBF Testing Set Metrics")
print(classification_report(y_test, svm_model.predict(x_test_scaled), target_names=target_names))
# Out:
# SVM-RBF Training Set Metrics
#               precision    recall  f1-score   support
#
#  Not At Risk       0.96      0.97      0.97      1115
#      At Risk       0.96      0.94      0.95       798
#
#     accuracy                           0.96      1913
#    macro avg       0.96      0.96      0.96      1913
# weighted avg       0.96      0.96      0.96      1913
#
# SVM-RBF Testing Set Metrics
#               precision    recall  f1-score   support
#
#  Not At Risk       0.94      0.94      0.94       273
#      At Risk       0.92      0.92      0.92       206
#
#     accuracy                           0.93       479
#    macro avg       0.93      0.93      0.93       479
# weighted avg       0.93      0.93      0.93       479

# %%
# SVM - Linear Kernel
svm_linear_model = svm.SVC(kernel = "linear", random_state = 88, probability = True)
svm_linear_model.fit(x_train_scaled, y_train)

print("Linear SVM Training Set")
classificationSummary(y_train, svm_linear_model.predict(x_train_scaled))
print("\nLinear SVM Testing Set")
classificationSummary(y_test, svm_linear_model.predict(x_test_scaled))
# Out:
# Linear SVM Training Set
# Confusion Matrix (Accuracy 0.9451)
#
#        Prediction
# Actual    0    1
#      0 1066   49
#      1   56  742
#
# Linear SVM Testing Set
# Confusion Matrix (Accuracy 0.9395)
#
#        Prediction
# Actual   0   1
#      0 256  17
#      1  12 194

# %%
#Evaluate Confusion Matrices of SVM - Linear Model

target_names = ['Not At Risk', 'At Risk']

print("SVM-Linear Training Set Metrics")
print(classification_report(y_train, svm_linear_model.predict(x_train_scaled), target_names=target_names))

print("SVM-Linear Testing Set Metrics")
print(classification_report(y_test, svm_linear_model.predict(x_test_scaled), target_names=target_names))
# Out:
# SVM-Linear Training Set Metrics
#               precision    recall  f1-score   support
#
#  Not At Risk       0.95      0.96      0.95      1115
#      At Risk       0.94      0.93      0.93       798
#
#     accuracy                           0.95      1913
#    macro avg       0.94      0.94      0.94      1913
# weighted avg       0.95      0.95      0.95      1913
#
# SVM-Linear Testing Set Metrics
#               precision    recall  f1-score   support
#
#  Not At Risk       0.96      0.94      0.95       273
#      At Risk       0.92      0.94      0.93       206
#
#     accuracy                           0.94       479
#    macro avg       0.94      0.94      0.94       479
# weighted avg       0.94      0.94      0.94       479

# %%
# SVM - Sigmoid Kernel
svm_sigmoid_model = svm.SVC(kernel = "sigmoid", random_state = 88, probability = True)
svm_sigmoid_model.fit(x_train_scaled, y_train)

print("Sigmoid SVM Training Set")
classificationSummary(y_train, svm_sigmoid_model.predict(x_train_scaled))
print("\nSigmoid SVM Testing Set")
classificationSummary(y_test, svm_sigmoid_model.predict(x_test_scaled))
# Out:
# Sigmoid SVM Training Set
# Confusion Matrix (Accuracy 0.7475)
#
#        Prediction
# Actual   0   1
#      0 876 239
#      1 244 554
#
# Sigmoid SVM Testing Set
# Confusion Matrix (Accuracy 0.7432)
#
#        Prediction
# Actual   0   1
#      0 218  55
#      1  68 138

# %%
#Evaluate Confusion Matrices of SVM - Sigmoid Model

target_names = ['Not At Risk', 'At Risk']

print("SVM-Sigmoid Training Set Metrics")
print(classification_report(y_train, svm_sigmoid_model.predict(x_train_scaled), target_names=target_names))

print("SVM-Sigmoid Testing Set Metrics")
print(classification_report(y_test, svm_sigmoid_model.predict(x_test_scaled), target_names=target_names))
# Out:
# SVM-Sigmoid Training Set Metrics
#               precision    recall  f1-score   support
#
#  Not At Risk       0.78      0.79      0.78      1115
#      At Risk       0.70      0.69      0.70       798
#
#     accuracy                           0.75      1913
#    macro avg       0.74      0.74      0.74      1913
# weighted avg       0.75      0.75      0.75      1913
#
# SVM-Sigmoid Testing Set Metrics
#               precision    recall  f1-score   support
#
#  Not At Risk       0.76      0.80      0.78       273
#      At Risk       0.72      0.67      0.69       206
#
#     accuracy                           0.74       479
#    macro avg       0.74      0.73      0.74       479
# weighted avg       0.74      0.74      0.74       479

# %%
# SVM - Poly Kernel
svm_poly_model = svm.SVC(kernel = "poly", random_state = 88, probability = True)
svm_poly_model.fit(x_train_scaled, y_train)

print("Polynomial SVM Training Set")
classificationSummary(y_train, svm_poly_model.predict(x_train_scaled))
print("\nPolynomial SVM Testing Set")
classificationSummary(y_test, svm_poly_model.predict(x_test_scaled))
# Out:
# Polynomial SVM Training Set
# Confusion Matrix (Accuracy 0.9634)
#
#        Prediction
# Actual    0    1
#      0 1091   24
#      1   46  752
#
# Polynomial SVM Testing Set
# Confusion Matrix (Accuracy 0.9186)
#
#        Prediction
# Actual   0   1
#      0 257  16
#      1  23 183

# %%
#Evaluate Confusion Matrices of SVM - Polynomial Model

target_names = ['Not At Risk', 'At Risk']

print("SVM-Polynomail Training Set Metrics")
print(classification_report(y_train, svm_poly_model.predict(x_train_scaled), target_names=target_names))

print("SVM-Polynomial Testing Set Metrics")
print(classification_report(y_test, svm_poly_model.predict(x_test_scaled), target_names=target_names))
# Out:
# SVM-Polynomail Training Set Metrics
#               precision    recall  f1-score   support
#
#  Not At Risk       0.96      0.98      0.97      1115
#      At Risk       0.97      0.94      0.96       798
#
#     accuracy                           0.96      1913
#    macro avg       0.96      0.96      0.96      1913
# weighted avg       0.96      0.96      0.96      1913
#
# SVM-Polynomial Testing Set Metrics
#               precision    recall  f1-score   support
#
#  Not At Risk       0.92      0.94      0.93       273
#      At Risk       0.92      0.89      0.90       206
#
#     accuracy                           0.92       479
#    macro avg       0.92      0.91      0.92       479
# weighted avg       0.92      0.92      0.92       479

# %%
# SVM - Comparing Various Kernels

#RBF
svmrbf_prob_pred = svm_model.predict_proba(x_test_scaled)
svmrbf_results = pd.DataFrame({"Actual": y_test, 
                               "p(0)": [i[0] for i in svmrbf_prob_pred], 
                               "p(1)" : [i[1] for i in svmrbf_prob_pred], 
                               "Predicted": svm_model.predict(x_test_scaled),
})

svmrbf_results = svmrbf_results.sort_values(by = ["p(1)"], ascending = False)

#Linear
svmlin_prob_pred = svm_linear_model.predict_proba(x_test_scaled)
svmlin_results = pd.DataFrame({"Actual": y_test, 
                               "p(0)": [i[0] for i in svmlin_prob_pred], 
                               "p(1)" : [i[1] for i in svmlin_prob_pred], 
                               "Predicted": svm_linear_model.predict(x_test_scaled),
})

svmlin_results = svmlin_results.sort_values(by = ["p(1)"], ascending = False)

#Sigmoid
svmsig_prob_pred = svm_sigmoid_model.predict_proba(x_test_scaled)
svmsig_results = pd.DataFrame({"Actual": y_test, 
                               "p(0)": [i[0] for i in svmsig_prob_pred], 
                               "p(1)" : [i[1] for i in svmsig_prob_pred], 
                               "Predicted": svm_sigmoid_model.predict(x_test_scaled),
})

svmsig_results = svmsig_results.sort_values(by = ["p(1)"], ascending = False)

#Polynomial
svmpoly_prob_pred = svm_poly_model.predict_proba(x_test_scaled)
svmpoly_results = pd.DataFrame({"Actual": y_test, 
                               "p(0)": [i[0] for i in svmpoly_prob_pred], 
                               "p(1)" : [i[1] for i in svmpoly_prob_pred], 
                               "Predicted": svm_poly_model.predict(x_test_scaled),
})

svmpoly_results = svmpoly_results.sort_values(by = ["p(1)"], ascending = False)

# %%
# Gains Chart for all SVM Models

fig, ax = plt.subplots(figsize = (8,6))
gainsChart(svmrbf_results["Actual"], label = "RBF", color = "r", ax = ax)
gainsChart(svmlin_results["Actual"], label = "Linear", color = "b", ax = ax)
gainsChart(svmsig_results["Actual"], label = "Sigmoid", color = "g", ax = ax)
gainsChart(svmpoly_results["Actual"], label = "Polynomial", color = "c", ax = ax)
plt.legend()
plt.title("Gains Chart for All SVM Kernels")

# Lift Charts
fig, axes = plt.subplots(
nrows = 1,
ncols = 4,
figsize = (15,6))
liftChart(svmrbf_results["Actual"], title = "SVM RBF Kernel Lift Chart", ax = axes[0])
liftChart(svmlin_results["Actual"], title = "SVM Linear Kernel Lift Chart", ax = axes[1])
liftChart(svmsig_results["Actual"], title = "SVM Sigmoid Kernel Lift Chart", ax = axes[2])
liftChart(svmpoly_results["Actual"], title = "SVM Polynomial Kernel Lift Chart", ax = axes[3])
fig.suptitle("Lift Charts by SVM Kernel")
# Out:
# Text(0.5, 0.98, 'Lift Charts by SVM Kernel')

# %%
#Area Under the ROC Curve (SVM Linear Model)

svmlin_proba_pred = svm_linear_model.predict_proba(x_test_scaled)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  svmlin_proba_pred)
auc = metrics.roc_auc_score(y_test, svmlin_proba_pred)
plt.plot(fpr,tpr,label="SVM Linear Kernel, AUC="+str(auc))
plt.legend(loc=4)
plt.show()

# %%
# Determining Feature Importance from Parameters of SVM-Linear Model

coefficients = svm_linear_model.coef_[0]

print("Intercept: ", svm_linear_model.intercept_[0])
print("\nCoefficients: ", sorted(zip(coefficients, x_train.columns), reverse=True))
# Out:
# Intercept:  -3.207673807316287
#
# Coefficients:  [(9.750003977100663, 'Absences'), (0.27531801800646116, 'Age'), (0.16000201404341752, 'Volunteering'), (0.15483287610758945, 'Gender'), (0.1495313430520172, 'Eth_Asian'), (0.05787384808592883, 'ParentalEducation'), (-0.05988512659280262, 'Eth_Black'), (-0.06834416255664166, 'Eth_Latino'), (-0.5277018805201088, 'Extracurricular'), (-0.5450488801712059, 'Sports'), (-0.6189797060861929, 'Music'), (-0.8055356710073034, 'Tutoring'), (-1.9510277742804327, 'StudyTimeWeekly'), (-1.9747864585286725, 'ParentalSupport')]

# %%
# Lift Charts for 2nd Logistic Regression Model & SVM-Linear Model
fig, axes = plt.subplots(
nrows = 1,
ncols = 2,
figsize = (15,6))
liftChart(logit_result2["Actual"], title = "Logistic Regression 2 Lift Chart", ax = axes[0])
liftChart(svmlin_results["Actual"], title = "SVM Linear Kernel Lift Chart", ax = axes[1])
fig.suptitle("Lift Charts for 2nd Logistic Regression Model & SVM Linear Model")
# Out:
# Text(0.5, 0.98, 'Lift Charts for 2nd Logistic Regression Model & SVM Linear Model')

# %%
# Gains Chart for 2nd Logistic Regression Model & SVM-Linear Model

fig, ax = plt.subplots(figsize = (8,6))
gainsChart(logit_result2["Actual"], label = "logit_reg2", color = "r", ax = ax)
gainsChart(svmlin_results["Actual"], label = "SVM Linear", color = "b", ax = ax)
plt.legend()
plt.title("Gains Chart for 2nd Logistic Regression Model & SVM Linear Model")
# Out:
# Text(0.5, 1.0, 'Gains Chart for 2nd Logistic Regression Model & SVM Linear Model')
